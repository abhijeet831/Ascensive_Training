# %% [markdown]
# ## Python Variable

# %%
text = '# hello World'
text
# Out:
# '# hello World'

# %%
# arithmetic operations
a = 10
b = 5   
print("add", a + b)
print("sub", a - b)
print("mul", a * b)
print("div", a / b)
# Out:
# add 15
# sub 5
# mul 50
# div 2.0

# %%
print("mod",a % b)
print('exp',a**b)
print('floor div',a//b)
print("int div",a/b)
# Out:
# mod 0
# exp 100000
# floor div 2
# int div 2.0

# %%
# escaping the quotes in string
str1 = 'doesn\'t'
str2 = "\"Yes,\"they said."
print(str1)
print(str2)
# Out:
# doesn't
# "Yes,"they said.

# %%
#type int/str
a = 5
print(type(a))
b = 'hello'
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# type casting 
print(int(4.7))
print(float(5))
print(str(6))
# Out:
# 4
# 5.0
# 6
