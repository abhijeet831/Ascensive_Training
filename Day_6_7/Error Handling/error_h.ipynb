# %%
print("hello")
# Out:
# hello

# %%
try:
    num = int("abc")
except ValueError :
    print("Conversion failed")
# Out:
# Conversion failed

# %%
try:
    file = open("data.txt")
except FileNotFoundError:
    print("")

# %%
try:
    value = int(input("Enter number"))
    result = 10 / value
except ValueError:
    print("Invalid input")
except ZeroDivisionError:
    print("Cannot divide by zero")

except (ValueError,TypeError):
    print("Invalid input or type")

# %%
try:
    file = open("data.txt")
except FileNotFoundError :
    print("File missing")
finally:
    print("Closing resources")
# Out:
# File missing
# Closing resources

# %%
def withdraw(balance,amount):
    if amount > balance:
        raise ValueError("Insufficient Balance")
    
    return balance - amount

# %%
print(withdraw(1000,1500))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(withdraw(1000,1500))
#
# Cell In[2], line 3, in withdraw(balance, amount)
#       1 def withdraw(balance,amount):
#       2     if amount > balance:
# ----> 3         raise ValueError("Insufficient Balance")
#       5     return balance - amount
#
# ValueError: Insufficient Balance

# %%
withdraw(1500,1000)
# Out:
# 500
