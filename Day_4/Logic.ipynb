# %%
# If/Else, For/While Loops, Comprehensions

# %%
age = 18

if age >= 18:
    print("You can have driving license")
else:
    print("cannot have driving license")
# Out:
# You can have driving license

# %%
mobiles = ["iphone", "samsung", "oneplus", "nokia"]

if "iphone" in mobiles:
    print("iphone is present")
else:
    print("iphone is not present")
# Out:
# iphone is present

# %%
b = 10
if b % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
age = 18

if age >= 18:
    print("can vote")
elif age == 17: 
    print("wait 1 year")
elif age == 16:
    print("wait 2 years")
else:
    print("cannot vote")
# Out:
# can vote

# %%
# for loops

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
count = 0 #-> initialization

while(count<=5):
    print(count) #-> termination
    count +=1 # increment
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
number = 2

while(number<=10):
    if number % 2 ==0:
        print(number,"even")
    else:
        print(number,"odd")
    number +=1
# Out:
# 2 even
# 3 odd
# 4 even
# 5 odd
# 6 even
# 7 odd
# 8 even
# 9 odd
# 10 even

# %%
if True : print("Helo") ; print("hello2")
# Out:
# Helo
# hello2

# %%
# Python’s Ternary Operator
b = 10
True if b == 10 else False
# Out:
# True

# %%
# comprehesion

result = []
something = [1,2,3,4,5,6]
for i in something:
    result.append(i)

print(result)

# using it
result2 = [i for i in something]
print(result2)

#more short
print([i for i in something])
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %%
square = []
for i in something:
    print(i**2,end=" ")
print()

square = [i*i for i in something]
print(square)
# Out:
# 1 4 9 16 25 36
# [1, 4, 9, 16, 25, 36]

# %%
even = [[i,"even"] for i in range(2,10) if i%2 ==0]
even
# Out:
# [[2, 'even'], [4, 'even'], [6, 'even'], [8, 'even']]

# %%
matrix = [[1,10],[2,20],[3,30],[4,40]]

result = [num for row in matrix for num in row]
print(result)
# Out:
# [1, 10, 2, 20, 3, 30, 4, 40]
